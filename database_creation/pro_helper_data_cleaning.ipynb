# %%
import pandas as pd
import re

# %% [markdown]
# Read the .csv containing all Pokémon info into a DataFrame

# %%
df = pd.read_csv('/content/pkm_info.csv')
df.head()
# Out:
#          name                                     evolution_info  \
# 0        Abra  It evolves into Kadabra as early as level 16; ...
# 1  Aerodactyl                                                NaN
# 2    Alakazam  Having evolved from Kadabra when involved in a...
# 3       Arbok  It evolves from Ekans as early as level 22, th...
# 4    Arcanine  It is the only evolutionary outlet of Growlith...
#
#                 types    Ability 1    Ability 2 Hidden Ability  HP  Atk  Def  \
# 0         ['Psychic']  Synchronize  Inner Focus    Magic Guard  25   20   15
# 1  ['Rock', 'Flying']    Rock Head     Pressure        Unnerve  80  105   65
# 2         ['Psychic']  Synchronize  Inner Focus    Magic Guard  55   50   45
# 3          ['Poison']   Intimidate    Shed Skin        Unnerve  60   85   69
# 4            ['Fire']   Intimidate   Flash Fire      Justified  90  110   80
#
#    Sp.Atk  Sp.Def  Spd catch_rate      rarity  \
# 0     105      55   90     26.14%    Uncommon
# 1      60      75  130      5.88%  Unhuntable
# 2     135      85  120      6.54%  Unhuntable
# 3      65      79   80     11.76%      Common
# 4     100      80   95       9.8%    Uncommon
#
#                                        obtainability
# 0                                   ['Wild', 'NPCs']
# 1  ['From diggable patches and Excavation Sites',...
# 2                                                 []
# 3                   ['Wild', 'Discontinued Methods']
# 4                                                 []

# %% [markdown]
# Some attributes, such as *types* are in a list, let's split them into separate columns

# %%
# Some attributes are in lists, let's split them into separate columns
for attribute in ['types']:
  # Remove [] and '
  df[attribute] = df[attribute].str.replace(r"[\[\]']", '', regex=True)
  if attribute != 'obtainability':
    # Find how many new columns will be created by each attribute split
    max_value = df[attribute].apply(lambda x: x.count(',') + 1).max()
    new_column_names = [f'{attribute}{x}' for x in range(1, max_value+1)]
    # Split into new columns
    df[new_column_names] = df[attribute].str.split(',', expand=True)
    # Drop original column
    df = df.drop(attribute, axis=1)

df.head()
# Out:
#          name                                     evolution_info    Ability 1  \
# 0        Abra  It evolves into Kadabra as early as level 16; ...  Synchronize
# 1  Aerodactyl                                                NaN    Rock Head
# 2    Alakazam  Having evolved from Kadabra when involved in a...  Synchronize
# 3       Arbok  It evolves from Ekans as early as level 22, th...   Intimidate
# 4    Arcanine  It is the only evolutionary outlet of Growlith...   Intimidate
#
#      Ability 2 Hidden Ability  HP  Atk  Def  Sp.Atk  Sp.Def  Spd catch_rate  \
# 0  Inner Focus    Magic Guard  25   20   15     105      55   90     26.14%
# 1     Pressure        Unnerve  80  105   65      60      75  130      5.88%
# 2  Inner Focus    Magic Guard  55   50   45     135      85  120      6.54%
# 3    Shed Skin        Unnerve  60   85   69      65      79   80     11.76%
# 4   Flash Fire      Justified  90  110   80     100      80   95       9.8%
#
#        rarity                                      obtainability   types1  \
# 0    Uncommon                                   ['Wild', 'NPCs']  Psychic
# 1  Unhuntable  ['From diggable patches and Excavation Sites',...     Rock
# 2  Unhuntable                                                 []  Psychic
# 3      Common                   ['Wild', 'Discontinued Methods']   Poison
# 4    Uncommon                                                 []     Fire
#
#     types2
# 0     None
# 1   Flying
# 2     None
# 3     None
# 4     None

# %% [markdown]
# Further cleaning and normalization is needed:

# %%
# Lowercase all column headers
df.columns = [x.lower() for x in df.columns]

# Replace . for _ if needed
df.columns = [re.sub('\.', '_', x) for x in df.columns]

# Correct typos
df = df.rename(columns={'types1': 'type1',
                        'types2': 'type2',
                        'ability 1': 'ability_1',
                        'ability 2': 'ability_2',
                        'hidden ability': 'hidden_ability'})

df.head()
# Out:
#          name                                     evolution_info    ability_1  \
# 0        Abra  It evolves into Kadabra as early as level 16; ...  Synchronize
# 1  Aerodactyl                                                NaN    Rock Head
# 2    Alakazam  Having evolved from Kadabra when involved in a...  Synchronize
# 3       Arbok  It evolves from Ekans as early as level 22, th...   Intimidate
# 4    Arcanine  It is the only evolutionary outlet of Growlith...   Intimidate
#
#      ability_2 hidden_ability  hp  atk  def  sp_atk  sp_def  spd catch_rate  \
# 0  Inner Focus    Magic Guard  25   20   15     105      55   90     26.14%
# 1     Pressure        Unnerve  80  105   65      60      75  130      5.88%
# 2  Inner Focus    Magic Guard  55   50   45     135      85  120      6.54%
# 3    Shed Skin        Unnerve  60   85   69      65      79   80     11.76%
# 4   Flash Fire      Justified  90  110   80     100      80   95       9.8%
#
#        rarity                                      obtainability    type1  \
# 0    Uncommon                                   ['Wild', 'NPCs']  Psychic
# 1  Unhuntable  ['From diggable patches and Excavation Sites',...     Rock
# 2  Unhuntable                                                 []  Psychic
# 3      Common                   ['Wild', 'Discontinued Methods']   Poison
# 4    Uncommon                                                 []     Fire
#
#      type2
# 0     None
# 1   Flying
# 2     None
# 3     None
# 4     None

# %% [markdown]
# Now let's read the .csv containing the Pokémon list and their generation

# %%
df_list = pd.read_csv('/content/pkm_list.csv')
df_list.head()
# Out:
#          name                                           wiki_url gen
# 0        Abra  https://wiki.pokemonrevolution.net/index.php?t...   I
# 1  Aerodactyl  https://wiki.pokemonrevolution.net/index.php?t...   I
# 2    Alakazam  https://wiki.pokemonrevolution.net/index.php?t...   I
# 3       Arbok  https://wiki.pokemonrevolution.net/index.php?t...   I
# 4    Arcanine  https://wiki.pokemonrevolution.net/index.php?t...   I

# %% [markdown]
# We can join both DataFrames by using the *name* attribute as index

# %%
df_merge = pd.concat([df.set_index('name'), df_list.set_index('name')], axis='columns')
df_merge.head()
# Out:
#                                                evolution_info    ability_1  \
# name
# Abra        It evolves into Kadabra as early as level 16; ...  Synchronize
# Aerodactyl                                                NaN    Rock Head
# Alakazam    Having evolved from Kadabra when involved in a...  Synchronize
# Arbok       It evolves from Ekans as early as level 22, th...   Intimidate
# Arcanine    It is the only evolutionary outlet of Growlith...   Intimidate
#
#               ability_2 hidden_ability  hp  atk  def  sp_atk  sp_def  spd  \
# name
# Abra        Inner Focus    Magic Guard  25   20   15     105      55   90
# Aerodactyl     Pressure        Unnerve  80  105   65      60      75  130
# Alakazam    Inner Focus    Magic Guard  55   50   45     135      85  120
# Arbok         Shed Skin        Unnerve  60   85   69      65      79   80
# Arcanine     Flash Fire      Justified  90  110   80     100      80   95
#
#            catch_rate      rarity  \
# name
# Abra           26.14%    Uncommon
# Aerodactyl      5.88%  Unhuntable
# Alakazam        6.54%  Unhuntable
# Arbok          11.76%      Common
# Arcanine         9.8%    Uncommon
#
#                                                 obtainability    type1  \
# name
# Abra                                         ['Wild', 'NPCs']  Psychic
# Aerodactyl  ['From diggable patches and Excavation Sites',...     Rock
# Alakazam                                                   []  Psychic
# Arbok                        ['Wild', 'Discontinued Methods']   Poison
# Arcanine                                                   []     Fire
#
#               type2                                           wiki_url gen
# name
# Abra           None  https://wiki.pokemonrevolution.net/index.php?t...   I
# Aerodactyl   Flying  https://wiki.pokemonrevolution.net/index.php?t...   I
# Alakazam       None  https://wiki.pokemonrevolution.net/index.php?t...   I
# Arbok          None  https://wiki.pokemonrevolution.net/index.php?t...   I
# Arcanine       None  https://wiki.pokemonrevolution.net/index.php?t...   I

# %% [markdown]
# *catch_rate* is in string format, let's transform it into a float

# %%
df_merge['catch_rate'] = df_merge['catch_rate'].str.replace('%', '').astype(float)

# %% [markdown]
# *gen* attribute is in roman numerals, we can exchange them for their alphanumeric counterpart

# %%
# List every different gen entry
gen_list = (df_merge.groupby('gen')
                    .count()
                    .reset_index()['gen']
                    .to_list())

# For every roman numeral, exchange it for its alphanumeric counterpart
for index, gen in enumerate(gen_list):
  df_merge.loc[(df_merge['gen'] == gen), 'gen'] = index+1

# %% [markdown]
# We can check if the transformation above was successful

# %%
df_merge.groupby('gen').count()
# Out:
#      evolution_info  ability_1  ability_2  hidden_ability   hp  atk  def  \
# gen
# 1               138        151         97             143  151  151  151
# 2                80        101         65              97  101  101  101
# 3               105        135         60             114  135  135  135
# 4                88        107         46              91  107  107  107
# 5               129        156        106             132  156  156  156
# 6                59         72         32              60   72   72   72
# 7                47         53         25              42   53   53   53
#
#      sp_atk  sp_def  spd  catch_rate  rarity  obtainability  type1  type2  \
# gen
# 1       151     151  151         151     151            151    151     67
# 2       101     101  101         101     101            101    101     50
# 3       135     135  135         135     135            135    135     66
# 4       107     107  107         107     107            107    107     53
# 5       156     156  156         156     156            156    156     74
# 6        72      72   72          72      72             72     72     41
# 7        53      53   53          53      53             53     53     33
#
#      wiki_url
# gen
# 1         151
# 2         101
# 3         135
# 4         107
# 5         156
# 6          72
# 7          53

# %% [markdown]
# Aaaand export!

# %%
df_merge.to_csv('pkm_info_clean.csv', index=False)
